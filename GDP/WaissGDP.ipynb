# %%
import folium
from folium.features import CustomIcon
import json
import pandas as pd
import geopandas as gpd

# %%
#Leer el geojson file con geopandas

yugo = gpd.read_file('/Users/agustincosovschi/Trabajo/ProduccionPropia/Artículos/WaissEspacial/Visuals/Selection/GDP/yugo.geojson')

# %%
#Explorar el geojson 

print(yugo.head(25))
# Out:
#    scalerank           featurecla  labelrank              sovereignt sov_a3  \
# 0          0  Admin-0 sovereignty        5.0  Bosnia and Herzegovina    BIH
# 1          0  Admin-0 sovereignty        6.0                 Croatia    HRV
# 2          0  Admin-0 sovereignty        6.0                  Kosovo    KOS
# 3          0  Admin-0 sovereignty        6.0               Macedonia    MKD
# 4          0  Admin-0 sovereignty        6.0              Montenegro    MNE
# 5          0  Admin-0 map subunit        NaN                  Serbia    SRB
# 6          0  Admin-0 map subunit        NaN               Vojvodina    VOJ
# 7          0  Admin-0 sovereignty        6.0                Slovenia    SVN
#
#    adm0_dif  level               type                   admin adm0_a3  ...  \
# 0       0.0    2.0  Sovereign country  Bosnia and Herzegovina     BIH  ...
# 1       0.0    2.0  Sovereign country                 Croatia     HRV  ...
# 2       0.0    2.0  Sovereign country                  Kosovo     KOS  ...
# 3       0.0    2.0  Sovereign country               Macedonia     MKD  ...
# 4       0.0    2.0  Sovereign country              Montenegro     MNE  ...
# 5       NaN    NaN               None                  Serbia    None  ...
# 6       NaN    NaN               None               Vojvodina    None  ...
# 7       0.0    2.0  Sovereign country                Slovenia     SVN  ...
#
#    CONTINENT REGION_UN        SUBREGION              REGION_WB NAME_LEN  \
# 0       None      None             None                   None      NaN
# 1       None      None             None                   None      NaN
# 2       None      None             None                   None      NaN
# 3       None      None             None                   None      NaN
# 4       None      None             None                   None      NaN
# 5     Europe    Europe  Southern Europe  Europe & Central Asia      6.0
# 6     Europe    Europe  Southern Europe  Europe & Central Asia      9.0
# 7       None      None             None                   None      NaN
#
#   LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 0      NaN         NaN   NaN      NaN
# 1      NaN         NaN   NaN      NaN
# 2      NaN         NaN   NaN      NaN
# 3      NaN         NaN   NaN      NaN
# 4      NaN         NaN   NaN      NaN
# 5      6.0         5.0 -99.0      1.0
# 6      9.0         5.0 -99.0      1.0
# 7      NaN         NaN   NaN      NaN
#
#                                             geometry
# 0  POLYGON ((16.94153 45.24122, 16.94732 45.23569...
# 1  MULTIPOLYGON (((16.93393 42.77094, 16.93637 42...
# 2  POLYGON ((20.86470 43.21734, 20.86160 43.21752...
# 3  POLYGON ((22.34502 42.31344, 22.44362 42.21443...
# 4  POLYGON ((19.05499 43.50670, 19.07639 43.50724...
# 5  POLYGON ((21.35984 44.82664, 21.36059 44.82641...
# 6  POLYGON ((19.79045 46.12907, 19.87365 46.15299...
# 7  POLYGON ((16.34343 46.71418, 16.35728 46.71583...
#
# [8 rows x 127 columns]

# %%
#Meto mis datos de un csv

republics = ['Bosnia and Herzegovina', 'Slovenia', 'Serbia', 'Vojvodina', 'Kosovo', 'Montenegro', 'Macedonia', 'Croatia']

gdp_per_capita = [83, 165, 91, 94, 43, 77, 68, 122]

df = pd.DataFrame(list(zip(republics, gdp_per_capita)), columns=['Republic/region', 'GDP per capita (index)'])

# %%
#Exploro el csv
print(df)
# Out:
#           Republic/region  GDP per capita (index)
# 0  Bosnia and Herzegovina                      83
# 1                Slovenia                     165
# 2                  Serbia                      91
# 3               Vojvodina                      94
# 4                  Kosovo                      43
# 5              Montenegro                      77
# 6               Macedonia                      68
# 7                 Croatia                     122

# %%
#Hago el mapa

m = folium.Map(location=[44, 19], tiles= 'cartodbpositron', zoom_start=6)



#colores : ‘scheme_info = {'BuGn': 'Sequential',
           #        'BuPu': 'Sequential',
            #       'GnBu': 'Sequential',
             #      'OrRd': 'Sequential',
              #     'PuBu': 'Sequential',
               #    'PuBuGn': 'Sequential',
                #  'PuRd': 'Sequential',
                 #  'RdPu': 'Sequential',
                 #  'YlGn': 'Sequential',
                  # 'YlGnBu': 'Sequential',
                   #'YlOrBr': 'Sequential',
            #       'YlOrRd': 'Sequential',
             #      'BrBg': 'Diverging',
              #     'PiYG': 'Diverging',
               #    'PRGn': 'Diverging',
               #    'PuOr': 'Diverging',
                #   'RdBu': 'Diverging',
                #   'RdGy': 'Diverging',
                #   'RdYlBu': 'Diverging',
                #   'RdYlGn': 'Diverging',
                ##   'Spectral': 'Diverging',
                #   'Accent': 'Qualitative',
                #   'Dark2': 'Qualitative',
                #   'Paired': 'Qualitative',
                #   'Pastel1': 'Qualitative',
                #   'Pastel2': 'Qualitative',
                #   'Set1': 'Qualitative',
                #   'Set2': 'Qualitative',
                #   'Set3': 'Qualitative',
                #   }.'

# %%
#Hago el Choropleth: geo_data es mi geojason, data es mi dataframe, columns son las columnas a rendear, 
#key_on es el key del geojason a tomar

bins = list(df['GDP per capita (index)'].quantile([0, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 1]))
print (bins)


folium.Choropleth(
    geo_data=yugo,
    name='choropleth',
    data=df,
    columns=['Republic/region', 'GDP per capita (index)'],
    key_on='feature.properties.sovereignt',
    fill_color='Greys',
    fill_opacity=1,
    line_opacity=1,
    legend_name='GDP index (1953). Yugoslavia=100.', 
    reset=True
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# [43.0, 60.5, 71.6, 77.60000000000001, 81.8, 87.0, 91.6, 93.7, 110.80000000000001, 134.89999999999998, 165.0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_waiss = pd.read_csv('/Users/agustincosovschi/Trabajo/ProduccionPropia/Artículos/WaissEspacial/Visuals/Selection/GDP/Localities_QGIS - Hoja 1.csv')

# %%
lats = []

for lat in df_waiss['Latitude']:
    lats.append(lat)

print(lats)
# Out:
# [46.3696591, 44.812557299999995, 46.214357799999995, 45.7788821, 46.0760348, 43.55, 46.557246299999996, 46.2428344, 41.5358885, 46.4367047, 45.3270631, 44.06989179999999, 45.899288500000004, 43.8579223, 41.1230977, 42.6506606, 44.6891667, 43.5081323]

# %%
longs = []

for lng in df_waiss['Longitude']:
    longs.append(lng)

print(longs)
# Out:
# [15.391852599999998, 20.463721, 14.5304464, 15.981861800000003, 15.6775854, 16.383333, 15.6457951, 14.355541699999998, 20.6958569, 14.0526057, 14.442176000000002, 22.098508600000002, 15.9477552, 18.4288885, 20.8016481, 18.0944238, 20.5161111, 16.4401935]

# %%
locs = []

for loc in df_waiss['Place']:
    locs.append(loc)

print(locs)
# Out:
# ['Zrece', 'Belgrade', 'Klanec', 'Zagreb', 'Kumrovec', 'Kaštela', 'Maribor', 'Kranj', 'Lazaropolje', 'Jesenica', 'Rijeka', 'Bor', 'Slijeme', 'Sarajevo', 'Ohrid', 'Dubrovnik', 'Avala', 'Split']

# %%
locations = [list(a) for a in zip(lats, longs, locs)]

# %%
print(locations)
# Out:
# [[46.3696591, 15.391852599999998, 'Zrece'], [44.812557299999995, 20.463721, 'Belgrade'], [46.214357799999995, 14.5304464, 'Klanec'], [45.7788821, 15.981861800000003, 'Zagreb'], [46.0760348, 15.6775854, 'Kumrovec'], [43.55, 16.383333, 'Kaštela'], [46.557246299999996, 15.6457951, 'Maribor'], [46.2428344, 14.355541699999998, 'Kranj'], [41.5358885, 20.6958569, 'Lazaropolje'], [46.4367047, 14.0526057, 'Jesenica'], [45.3270631, 14.442176000000002, 'Rijeka'], [44.06989179999999, 22.098508600000002, 'Bor'], [45.899288500000004, 15.9477552, 'Slijeme'], [43.8579223, 18.4288885, 'Sarajevo'], [41.1230977, 20.8016481, 'Ohrid'], [42.6506606, 18.0944238, 'Dubrovnik'], [44.6891667, 20.5161111, 'Avala'], [43.5081323, 16.4401935, 'Split']]

# %%
for location in locations:    
    folium.Marker([location[0],location[1]], popup=location[2],
                  icon=folium.Icon(color='darkred', icon='user')
                 
                 ).add_to(m)
    

    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('/Users/agustincosovschi/Trabajo/ProduccionPropia/Artículos/WaissEspacial/Visuals/Selection/GDP/WaissXGDP_User.html')
